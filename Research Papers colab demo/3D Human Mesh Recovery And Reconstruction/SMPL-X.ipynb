# %%
# !git clone https://github.com/vchoutas/smplx.git
# Out:
# Cloning into 'smplx'...
# remote: Enumerating objects: 102, done.
# remote: Counting objects: 100% (102/102), done.
# remote: Compressing objects: 100% (65/65), done.
# remote: Total 476 (delta 53), reused 85 (delta 37), pack-reused 374
# Receiving objects: 100% (476/476), 1.01 MiB | 24.58 MiB/s, done.
# Resolving deltas: 100% (278/278), done.

# %%
cd smplx/
# Out:
# /content/smplx

# %%
# !pip install -r requirements.txt
# Out:
# Requirement already satisfied: numpy>=1.16.2 in /usr/local/lib/python3.6/dist-packages (from -r requirements.txt (line 1)) (1.19.5)
# Requirement already satisfied: torch>=1.0.1.post2 in /usr/local/lib/python3.6/dist-packages (from -r requirements.txt (line 2)) (1.7.0+cu101)
# Requirement already satisfied: dataclasses>=0.6 in /usr/local/lib/python3.6/dist-packages (from -r requirements.txt (line 3)) (0.8)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.6/dist-packages (from torch>=1.0.1.post2->-r requirements.txt (line 2)) (3.7.4.3)
# Requirement already satisfied: future in /usr/local/lib/python3.6/dist-packages (from torch>=1.0.1.post2->-r requirements.txt (line 2)) (0.16.0)

# %%
# !git clone https://github.com/vchoutas/torch-trust-ncg.git
# Out:
# Cloning into 'torch-trust-ncg'...
# remote: Enumerating objects: 16, done.
# remote: Counting objects: 100% (16/16), done.
# remote: Compressing objects: 100% (13/13), done.
# remote: Total 16 (delta 2), reused 13 (delta 1), pack-reused 0
# Unpacking objects: 100% (16/16), done.

# %%
# !python setup.py install
# Out:
# running install
# running bdist_egg
# running egg_info
# creating smplx.egg-info
# writing smplx.egg-info/PKG-INFO
# writing dependency_links to smplx.egg-info/dependency_links.txt
# writing requirements to smplx.egg-info/requires.txt
# writing top-level names to smplx.egg-info/top_level.txt
# writing manifest file 'smplx.egg-info/SOURCES.txt'
# writing manifest file 'smplx.egg-info/SOURCES.txt'
# installing library code to build/bdist.linux-x86_64/egg
# running install_lib
# running build_py
# creating build
# creating build/lib
# creating build/lib/smplx
# copying smplx/lbs.py -> build/lib/smplx
# copying smplx/vertex_joint_selector.py -> build/lib/smplx
# copying smplx/vertex_ids.py -> build/lib/smplx
# copying smplx/body_models.py -> build/lib/smplx
# copying smplx/joint_names.py -> build/lib/smplx
# copying smplx/utils.py -> build/lib/smplx
# copying smplx/__init__.py -> build/lib/smplx
# creating build/bdist.linux-x86_64
# creating build/bdist.linux-x86_64/egg
# creating build/bdist.linux-x86_64/egg/smplx
# copying build/lib/smplx/lbs.py -> build/bdist.linux-x86_64/egg/smplx
# copying build/lib/smplx/vertex_joint_selector.py -> build/bdist.linux-x86_64/egg/smplx
# copying build/lib/smplx/vertex_ids.py -> build/bdist.linux-x86_64/egg/smplx
# copying build/lib/smplx/body_models.py -> build/bdist.linux-x86_64/egg/smplx
# copying build/lib/smplx/joint_names.py -> build/bdist.linux-x86_64/egg/smplx
# copying build/lib/smplx/utils.py -> build/bdist.linux-x86_64/egg/smplx
# copying build/lib/smplx/__init__.py -> build/bdist.linux-x86_64/egg/smplx
# byte-compiling build/bdist.linux-x86_64/egg/smplx/lbs.py to lbs.cpython-36.pyc
# byte-compiling build/bdist.linux-x86_64/egg/smplx/vertex_joint_selector.py to vertex_joint_selector.cpython-36.pyc
# byte-compiling build/bdist.linux-x86_64/egg/smplx/vertex_ids.py to vertex_ids.cpython-36.pyc
# byte-compiling build/bdist.linux-x86_64/egg/smplx/body_models.py to body_models.cpython-36.pyc
# byte-compiling build/bdist.linux-x86_64/egg/smplx/joint_names.py to joint_names.cpython-36.pyc
# byte-compiling build/bdist.linux-x86_64/egg/smplx/utils.py to utils.cpython-36.pyc
# byte-compiling build/bdist.linux-x86_64/egg/smplx/__init__.py to __init__.cpython-36.pyc
# creating build/bdist.linux-x86_64/egg/EGG-INFO
# copying smplx.egg-info/PKG-INFO -> build/bdist.linux-x86_64/egg/EGG-INFO
# copying smplx.egg-info/SOURCES.txt -> build/bdist.linux-x86_64/egg/EGG-INFO
# copying smplx.egg-info/dependency_links.txt -> build/bdist.linux-x86_64/egg/EGG-INFO
# copying smplx.egg-info/requires.txt -> build/bdist.linux-x86_64/egg/EGG-INFO
# copying smplx.egg-info/top_level.txt -> build/bdist.linux-x86_64/egg/EGG-INFO
# zip_safe flag not set; analyzing archive contents...
# creating dist
# creating 'dist/smplx-0.1.26-py3.6.egg' and adding 'build/bdist.linux-x86_64/egg' to it
# removing 'build/bdist.linux-x86_64/egg' (and everything under it)
# Processing smplx-0.1.26-py3.6.egg
# Copying smplx-0.1.26-py3.6.egg to /usr/local/lib/python3.6/dist-packages
# Adding smplx 0.1.26 to easy-install.pth file
#
# Installed /usr/local/lib/python3.6/dist-packages/smplx-0.1.26-py3.6.egg
# Processing dependencies for smplx==0.1.26
# Searching for torchgeometry>=0.1.2
# Reading https://pypi.org/simple/torchgeometry/
# Downloading https://files.pythonhosted.org/packages/a6/d6/3f6820c0589bc3876080c59b58a3bad11af746a7b46f364b1cde7972bd72/torchgeometry-0.1.2-py2.py3-none-any.whl#sha256=f4b08b19359581f76aa93206fac4b439fbe784be2f072fca7d7e720bf0e28ce0
# Best match: torchgeometry 0.1.2
# Processing torchgeometry-0.1.2-py2.py3-none-any.whl
# Installing torchgeometry-0.1.2-py2.py3-none-any.whl to /usr/local/lib/python3.6/dist-packages
# Adding torchgeometry 0.1.2 to easy-install.pth file
#
# Installed /usr/local/lib/python3.6/dist-packages/torchgeometry-0.1.2-py3.6.egg
# Searching for torch==1.7.0+cu101
# Best match: torch 1.7.0+cu101
# Adding torch 1.7.0+cu101 to easy-install.pth file
# Installing convert-caffe2-to-onnx script to /usr/local/bin
# Installing convert-onnx-to-caffe2 script to /usr/local/bin
#
# Using /usr/local/lib/python3.6/dist-packages
# Searching for numpy==1.19.5
# Best match: numpy 1.19.5
# Adding numpy 1.19.5 to easy-install.pth file
# Installing f2py script to /usr/local/bin
# Installing f2py3 script to /usr/local/bin
# Installing f2py3.6 script to /usr/local/bin
#
# Using /usr/local/lib/python3.6/dist-packages
# Searching for dataclasses==0.8
# Best match: dataclasses 0.8
# Adding dataclasses 0.8 to easy-install.pth file
#
# Using /usr/local/lib/python3.6/dist-packages
# Searching for typing-extensions==3.7.4.3
# Best match: typing-extensions 3.7.4.3
# Adding typing-extensions 3.7.4.3 to easy-install.pth file
#
# Using /usr/local/lib/python3.6/dist-packages
# Searching for future==0.16.0
# Best match: future 0.16.0
# Adding future 0.16.0 to easy-install.pth file
# Installing futurize script to /usr/local/bin
# Installing pasteurize script to /usr/local/bin
#
# Using /usr/local/lib/python3.6/dist-packages
# Finished processing dependencies for smplx==0.1.26

# %%
# !python setup.py build develop
# Out:
# running build
# running build_py
# running develop
# running egg_info
# writing smplx.egg-info/PKG-INFO
# writing dependency_links to smplx.egg-info/dependency_links.txt
# writing requirements to smplx.egg-info/requires.txt
# writing top-level names to smplx.egg-info/top_level.txt
# writing manifest file 'smplx.egg-info/SOURCES.txt'
# running build_ext
# Creating /usr/local/lib/python3.6/dist-packages/smplx.egg-link (link to .)
# Removing smplx 0.1.26 from easy-install.pth file
# Adding smplx 0.1.26 to easy-install.pth file
#
# Installed /content/smplx
# Processing dependencies for smplx==0.1.26
# Searching for torchgeometry==0.1.2
# Best match: torchgeometry 0.1.2
# Processing torchgeometry-0.1.2-py3.6.egg
# torchgeometry 0.1.2 is already the active version in easy-install.pth
#
# Using /usr/local/lib/python3.6/dist-packages/torchgeometry-0.1.2-py3.6.egg
# Searching for torch==1.7.0+cu101
# Best match: torch 1.7.0+cu101
# Adding torch 1.7.0+cu101 to easy-install.pth file
# Installing convert-caffe2-to-onnx script to /usr/local/bin
# Installing convert-onnx-to-caffe2 script to /usr/local/bin
#
# Using /usr/local/lib/python3.6/dist-packages
# Searching for numpy==1.19.5
# Best match: numpy 1.19.5
# Adding numpy 1.19.5 to easy-install.pth file
# Installing f2py script to /usr/local/bin
# Installing f2py3 script to /usr/local/bin
# Installing f2py3.6 script to /usr/local/bin
#
# Using /usr/local/lib/python3.6/dist-packages
# Searching for future==0.16.0
# Best match: future 0.16.0
# Adding future 0.16.0 to easy-install.pth file
# Installing futurize script to /usr/local/bin
# Installing pasteurize script to /usr/local/bin
#
# Using /usr/local/lib/python3.6/dist-packages
# Searching for typing-extensions==3.7.4.3
# Best match: typing-extensions 3.7.4.3
# Adding typing-extensions 3.7.4.3 to easy-install.pth file
#
# Using /usr/local/lib/python3.6/dist-packages
# Searching for dataclasses==0.8
# Best match: dataclasses 0.8
# Adding dataclasses 0.8 to easy-install.pth file
#
# Using /usr/local/lib/python3.6/dist-packages
# Finished processing dependencies for smplx==0.1.26

# %%
# !python -m torchtrustncg
# Out:
# /usr/bin/python3: No module named torchtrustncg

# %%
pwd
# Out:
# '/content/smplx'

# %%
# !mkdir transfer_data

# %%
# %cd transfer_data
# Out:
# /content/smplx/transfer_data

# %%
# !unzip "model_transfer.zip"
# Out:
# Archive:  model_transfer.zip
#   inflating: smpl2smplh_def_transfer.pkl
#   inflating: smpl2smplx_deftrafo_setup.pkl
#   inflating: smplh2smpl_def_transfer.pkl
#   inflating: smplh2smplx_deftrafo_setup.pkl
#   inflating: smplx2smpl_deftrafo_setup.pkl
#   inflating: smplx2smplh_deftrafo_setup.pkl
#   inflating: smplx_mask_ids.npy

# %%
# !mkdir meshes

# %%
cd meshes/
# Out:
# /content/smplx/transfer_data/meshes

# %%
# !mkdir smpl
# !mkdir smplx
