# %%
# !git clone https://github.com/ahmedosman/STAR.git
# Out:
# Cloning into 'STAR'...
# remote: Enumerating objects: 103, done.
# remote: Counting objects: 100% (103/103), done.
# remote: Compressing objects: 100% (62/62), done.
# remote: Total 302 (delta 54), reused 81 (delta 38), pack-reused 199
# Receiving objects: 100% (302/302), 8.97 MiB | 10.05 MiB/s, done.
# Resolving deltas: 100% (162/162), done.

# %%
# !pip install chumpy==0.69
# !pip install opencv-python

# %%
# !pip install torch==1.6

# %%
# !pip install tensorflow-gpu==2.3

# %%
cd STAR
# Out:
# /content/STAR

# %%
# !unzip "star_1_1.zip"
# Out:
# Archive:  star_1_1.zip
#    creating: star_1_1/
#   inflating: star_1_1/LICENSE.txt
#    creating: star_1_1/female/
#   inflating: star_1_1/female/model.npz
#    creating: star_1_1/neutral/
#   inflating: star_1_1/neutral/model.npz
#    creating: star_1_1/male/
#   inflating: star_1_1/male/model.npz

# %%
# !pip install .
# Out:
# Processing /content/STAR
# ...
#   Created wheel for star: filename=star-0.0.1-cp36-none-any.whl size=27853 sha256=b1375fe0187084703bf0981245cad66a66c9db91c845b7a8978bf91045c4a94c
#   Stored in directory: /tmp/pip-ephem-wheel-cache-qzz_h4bw/wheels/d0/43/0a/d52c684b526370efbf30db4149141b07c5421de4c04fc58145
# Successfully built star
# ...
